# %%
#import packages and load data
import numpy as np
import pandas as pd
import datetime as dt
data = pd.read_excel("2019 Product BI Analyst Case Interview (2) (3).xlsx",sheet_name = 'Webinar Comments')
data.head()
# Out:
#            Rating Date                                      Webinar Title  \
# 0  2019-01-19 10:00:00  Channel Security Experts Deep Dive: The Anatom...
# 1  2019-01-19 10:00:00  Channel Security Experts Deep Dive: The Anatom...
# 2  2019-01-19 10:00:00  Channel Security Experts Deep Dive: The Anatom...
# 3  2019-01-19 10:00:00  Channel Security Experts Deep Dive: The Anatom...
# 4  2019-01-19 10:00:00  Channel Security Experts Deep Dive: The Anatom...
#
#                                              Comment  Rating
# 0                                                  -       4
# 1  interessanti spunti da approfondire soprattuto...       4
# 2                                                  -       4
# 3                                                  -       1
# 4                                                  -       4

# %%
#check data types for each column
data.dtypes
# Out:
# Rating Date      object
# Webinar Title    object
# Comment          object
# Rating            int64
# dtype: object

# %%
#describe numerical columns. can see no outliers for ratings as they stay on 1-5 scale. 
data.describe()
# Out:
#              Rating
# count  20670.000000
# mean       4.136284
# std        0.824450
# min        1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000

# %%
#describe categorical columns
data.describe(include= 'object')
# Out:
#                 Rating Date  \
# count                 20670
# unique                  839
# top     2019-01-10 16:00:00
# freq                    212
#
#                                             Webinar Title Comment
# count                                               20670   20670
# unique                                                235    2018
# top     [OnDemand Webinar] Channel Security Experts De...       -
# freq                                                  618   16888

# %%
#Check for null values across columns
data.isnull().sum()
# Out:
# Rating Date      0
# Webinar Title    0
# Comment          0
# Rating           0
# dtype: int64

# %%
data.isnull().values.any()
# Out:
# False

# %%
#20670 rows, 4 columns as expected
data.shape
# Out:
# (20670, 4)

# %%
#ensure all non-comments coded the same way in 'Comment' field. 

#convert data type of 'Comment' field to string
data['Comment'] = data['Comment'].astype('str')
#Create new field that establishes character length of Comments. 
data['Comment Length'] = data['Comment'].str.len()
#Create subset of data to capture all non-comments 
no_comment = data[data['Comment Length'] < 4] 
#value counts
no_comment['Comment'].value_counts()
# Out:
# -      16888
# 0        324
# 4          8
# 5          5
# 4.5        3
# x          2
# na         1
# 4.8        1
# Name: Comment, dtype: int64

# %%
#normalizing various values without comment to 'no comment'

no_comment_lst = ['-','0','4.5','x','na','4.8']
data['Comment'] = data['Comment'].replace(no_comment_lst,'no comment')

# %%
#spot check on Rating Date column to inspect why it is not datetime object
data['Rating Date'].unique()
# Out:
# array([datetime.datetime(2019, 1, 19, 10, 0),
#        datetime.datetime(2017, 12, 14, 16, 0),
#        datetime.datetime(2019, 3, 7, 18, 0),
#        datetime.datetime(2019, 3, 7, 15, 0),
#        datetime.datetime(2018, 12, 2, 18, 0),
#        datetime.datetime(2018, 12, 2, 15, 0),
#        datetime.datetime(2019, 4, 25, 15, 0),
#        datetime.datetime(2019, 4, 25, 12, 0),
#        datetime.datetime(2019, 1, 11, 16, 0),
#        datetime.datetime(2019, 1, 11, 13, 0),
#        datetime.datetime(2019, 5, 2, 15, 0),
#        datetime.datetime(2019, 5, 2, 12, 0),
#        datetime.datetime(2019, 2, 1, 16, 0),
#        datetime.datetime(2019, 2, 1, 13, 0),
#        datetime.datetime(2018, 4, 6, 15, 0),
#        datetime.datetime(2018, 4, 6, 12, 0),
#        datetime.datetime(2019, 3, 1, 18, 0),
#        datetime.datetime(2019, 3, 1, 15, 0),
#        datetime.datetime(2018, 3, 22, 15, 0),
#        datetime.datetime(2018, 6, 9, 16, 0),
#        datetime.datetime(2018, 6, 9, 13, 0),
#        datetime.datetime(2019, 2, 7, 17, 0),
#        datetime.datetime(2019, 2, 7, 16, 0),
#        datetime.datetime(2019, 2, 7, 14, 0),
#        datetime.datetime(2019, 1, 31, 17, 0),
#        datetime.datetime(2019, 1, 31, 14, 0),
#        datetime.datetime(2019, 2, 23, 17, 0),
#        datetime.datetime(2019, 2, 23, 14, 0),
#        datetime.datetime(2018, 10, 20, 16, 0),
#        datetime.datetime(2018, 10, 20, 13, 0),
#        datetime.datetime(2018, 7, 7, 16, 0),
#        datetime.datetime(2018, 7, 7, 13, 0),
#        datetime.datetime(2019, 3, 28, 17, 0),
#        datetime.datetime(2019, 3, 28, 14, 0),
#        datetime.datetime(2018, 6, 1, 15, 0),
#        datetime.datetime(2018, 6, 1, 12, 0),
#        datetime.datetime(2018, 2, 9, 16, 0),
#        datetime.datetime(2018, 2, 9, 13, 0),
#        datetime.datetime(2019, 4, 3, 15, 0),
#        datetime.datetime(2018, 9, 7, 14, 0),
#        datetime.datetime(2018, 5, 3, 16, 0),
#        datetime.datetime(2018, 5, 3, 13, 0),
#        datetime.datetime(2018, 8, 17, 15, 0),
#        datetime.datetime(2018, 8, 17, 12, 0),
#        datetime.datetime(2019, 1, 26, 18, 0),
#        datetime.datetime(2019, 1, 26, 15, 0),
#        datetime.datetime(2019, 3, 28, 15, 0),
#        datetime.datetime(2019, 3, 28, 12, 0),
#        datetime.datetime(2018, 9, 8, 15, 0),
#        datetime.datetime(2018, 9, 8, 12, 0),
#        datetime.datetime(2018, 8, 10, 16, 0),
#        datetime.datetime(2018, 8, 10, 13, 0),
#        datetime.datetime(2018, 12, 2, 17, 0),
#        datetime.datetime(2018, 12, 2, 13, 0),
#        datetime.datetime(2018, 9, 16, 16, 0),
#        datetime.datetime(2018, 9, 16, 12, 0),
#        datetime.datetime(2018, 10, 14, 16, 0),
#        datetime.datetime(2018, 10, 14, 12, 0),
#        datetime.datetime(2018, 12, 16, 17, 0),
#        datetime.datetime(2018, 12, 16, 13, 0),
#        datetime.datetime(2018, 11, 11, 13, 0),
#        datetime.datetime(2018, 10, 28, 16, 0),
#        datetime.datetime(2018, 10, 28, 12, 0),
#        datetime.datetime(2018, 9, 27, 5, 0),
#        datetime.datetime(2018, 9, 2, 16, 0),
#        datetime.datetime(2018, 9, 2, 12, 0),
#        datetime.datetime(2018, 7, 22, 16, 0),
#        datetime.datetime(2018, 7, 22, 12, 0),
#        datetime.datetime(2018, 11, 18, 16, 0),
#        datetime.datetime(2018, 11, 18, 13, 0),
#        datetime.datetime(2018, 8, 19, 12, 0),
#        datetime.datetime(2018, 9, 30, 16, 0),
#        datetime.datetime(2018, 9, 30, 12, 0),
#        datetime.datetime(2018, 8, 5, 16, 0),
#        datetime.datetime(2018, 8, 5, 13, 0),
#        datetime.datetime(2018, 4, 14, 17, 0),
#        datetime.datetime(2018, 4, 14, 14, 0),
#        datetime.datetime(2018, 8, 30, 15, 0),
#        datetime.datetime(2019, 4, 19, 16, 0),
#        datetime.datetime(2019, 4, 19, 13, 0),
#        datetime.datetime(2019, 1, 18, 18, 0),
#        datetime.datetime(2019, 1, 18, 15, 0),
#        datetime.datetime(2018, 6, 30, 16, 0),
#        datetime.datetime(2018, 6, 30, 13, 0),
#        datetime.datetime(2018, 4, 21, 16, 0),
#        datetime.datetime(2018, 4, 21, 13, 0),
#        datetime.datetime(2018, 2, 24, 17, 0),
#        datetime.datetime(2018, 2, 24, 14, 0),
#        datetime.datetime(2018, 2, 9, 18, 0),
#        datetime.datetime(2018, 2, 9, 15, 0),
#        datetime.datetime(2017, 12, 1, 18, 0),
#        datetime.datetime(2017, 12, 1, 15, 0),
#        datetime.datetime(2018, 6, 1, 17, 0),
#        datetime.datetime(2018, 6, 1, 14, 0),
#        datetime.datetime(2019, 4, 12, 17, 0),
#        datetime.datetime(2019, 4, 12, 14, 0),
#        datetime.datetime(2018, 5, 4, 17, 0),
#        datetime.datetime(2018, 5, 4, 14, 0),
#        datetime.datetime(2018, 9, 22, 17, 0),
#        datetime.datetime(2018, 9, 22, 14, 0),
#        datetime.datetime(2018, 4, 7, 16, 0),
#        datetime.datetime(2018, 4, 7, 13, 0),
#        datetime.datetime(2018, 6, 16, 16, 0),
#        datetime.datetime(2018, 6, 16, 13, 0),
#        datetime.datetime(2018, 5, 11, 16, 0),
#        datetime.datetime(2018, 5, 11, 13, 0),
#        datetime.datetime(2018, 7, 28, 17, 0),
#        datetime.datetime(2018, 7, 28, 14, 0),
#        datetime.datetime(2018, 11, 21, 18, 0),
#        datetime.datetime(2018, 11, 21, 15, 0), '2/29/2019  4:00:00 PM',
#        '2/29/2019  1:00:00 PM', datetime.datetime(2018, 8, 4, 16, 0),
#        datetime.datetime(2018, 8, 4, 13, 0),
#        datetime.datetime(2018, 11, 1, 16, 0),
#        datetime.datetime(2018, 11, 1, 13, 0),
#        datetime.datetime(2018, 3, 15, 16, 0),
#        datetime.datetime(2018, 3, 15, 13, 0),
#        datetime.datetime(2018, 3, 31, 17, 0),
#        datetime.datetime(2018, 3, 31, 14, 0),
#        datetime.datetime(2018, 1, 12, 18, 0),
#        datetime.datetime(2018, 1, 12, 15, 0),
#        datetime.datetime(2019, 4, 26, 16, 0),
#        datetime.datetime(2019, 4, 26, 13, 0),
#        datetime.datetime(2019, 1, 25, 17, 0),
#        datetime.datetime(2019, 1, 25, 14, 0),
#        datetime.datetime(2018, 10, 18, 16, 0),
#        datetime.datetime(2018, 10, 18, 13, 0),
#        datetime.datetime(2018, 6, 23, 16, 0),
#        datetime.datetime(2018, 6, 23, 13, 0),
#        datetime.datetime(2019, 1, 5, 18, 0),
#        datetime.datetime(2019, 1, 5, 15, 0),
#        datetime.datetime(2018, 9, 8, 17, 0),
#        datetime.datetime(2018, 9, 8, 14, 0),
#        datetime.datetime(2018, 8, 2, 16, 0),
#        datetime.datetime(2018, 8, 2, 13, 0),
#        datetime.datetime(2019, 5, 14, 15, 0),
#        datetime.datetime(2018, 11, 17, 17, 0),
#        datetime.datetime(2018, 11, 17, 14, 0),
#        datetime.datetime(2018, 8, 11, 17, 0),
#        datetime.datetime(2018, 8, 11, 14, 0),
#        datetime.datetime(2018, 12, 7, 18, 0),
#        datetime.datetime(2018, 12, 7, 15, 0),
#        datetime.datetime(2018, 7, 19, 15, 0),
#        datetime.datetime(2018, 5, 18, 15, 0),
#        datetime.datetime(2018, 5, 18, 12, 0),
#        datetime.datetime(2019, 2, 9, 17, 0),
#        datetime.datetime(2019, 2, 9, 14, 0),
#        datetime.datetime(2019, 2, 8, 16, 0),
#        datetime.datetime(2019, 2, 8, 13, 0),
#        datetime.datetime(2018, 8, 3, 17, 0),
#        datetime.datetime(2018, 8, 3, 14, 0),
#        datetime.datetime(2018, 3, 29, 15, 0),
#        datetime.datetime(2019, 5, 24, 0, 0),
#        datetime.datetime(2019, 2, 15, 18, 0),
#        datetime.datetime(2019, 2, 15, 15, 0),
#        datetime.datetime(2018, 6, 2, 17, 0),
#        datetime.datetime(2018, 6, 2, 14, 0),
#        datetime.datetime(2018, 4, 6, 17, 0),
#        datetime.datetime(2018, 4, 6, 14, 0),
#        datetime.datetime(2019, 1, 4, 16, 0),
#        datetime.datetime(2019, 1, 4, 13, 0),
#        datetime.datetime(2018, 11, 29, 16, 0),
#        datetime.datetime(2019, 1, 3, 16, 0),
#        datetime.datetime(2019, 1, 24, 16, 0),
#        datetime.datetime(2018, 2, 3, 16, 0),
#        datetime.datetime(2018, 2, 3, 13, 0),
#        datetime.datetime(2018, 12, 15, 17, 0),
#        datetime.datetime(2018, 12, 15, 14, 0),
#        datetime.datetime(2018, 12, 6, 16, 0),
#        datetime.datetime(2018, 11, 8, 16, 0),
#        datetime.datetime(2018, 7, 27, 15, 0),
#        datetime.datetime(2018, 7, 27, 12, 0),
#        datetime.datetime(2018, 5, 4, 15, 0),
#        datetime.datetime(2018, 5, 4, 12, 0),
#        datetime.datetime(2018, 3, 18, 17, 0),
#        datetime.datetime(2018, 3, 18, 14, 0),
#        datetime.datetime(2018, 8, 24, 16, 0),
#        datetime.datetime(2018, 8, 24, 13, 0),
#        datetime.datetime(2019, 3, 21, 17, 0),
#        datetime.datetime(2019, 3, 21, 14, 0),
#        datetime.datetime(2018, 9, 21, 17, 0),
#        datetime.datetime(2018, 9, 21, 14, 0),
#        datetime.datetime(2018, 2, 17, 18, 0),
#        datetime.datetime(2018, 2, 17, 15, 0),
#        datetime.datetime(2018, 11, 16, 16, 0),
#        datetime.datetime(2018, 11, 16, 13, 0),
#        datetime.datetime(2017, 12, 2, 18, 0),
#        datetime.datetime(2017, 12, 2, 15, 0),
#        datetime.datetime(2018, 9, 14, 15, 0),
#        datetime.datetime(2018, 9, 14, 12, 0),
#        datetime.datetime(2019, 5, 9, 15, 0),
#        datetime.datetime(2019, 5, 9, 12, 0),
#        datetime.datetime(2018, 5, 10, 15, 0),
#        datetime.datetime(2018, 5, 25, 16, 0),
#        datetime.datetime(2018, 5, 25, 13, 0),
#        datetime.datetime(2018, 2, 15, 17, 0),
#        datetime.datetime(2018, 2, 15, 14, 0),
#        datetime.datetime(2018, 9, 13, 15, 0),
#        datetime.datetime(2018, 5, 17, 16, 0),
#        datetime.datetime(2018, 5, 17, 13, 0),
#        datetime.datetime(2018, 5, 5, 17, 0),
#        datetime.datetime(2018, 5, 5, 14, 0),
#        datetime.datetime(2018, 2, 3, 18, 0),
#        datetime.datetime(2018, 2, 3, 15, 0),
#        datetime.datetime(2019, 5, 8, 15, 0),
#        datetime.datetime(2018, 2, 15, 16, 0),
#        datetime.datetime(2018, 8, 3, 15, 0),
#        datetime.datetime(2018, 8, 3, 12, 0), '2/29/2019  6:00:00 PM',
#        '2/29/2019  3:00:00 PM', datetime.datetime(2018, 6, 28, 15, 0),
#        datetime.datetime(2018, 10, 6, 17, 0),
#        datetime.datetime(2018, 10, 6, 14, 0),
#        datetime.datetime(2018, 8, 30, 16, 0),
#        datetime.datetime(2018, 8, 30, 13, 0),
#        datetime.datetime(2019, 3, 29, 16, 0),
#        datetime.datetime(2019, 3, 29, 13, 0),
#        datetime.datetime(2018, 6, 8, 17, 0),
#        datetime.datetime(2018, 6, 8, 14, 0),
#        datetime.datetime(2017, 12, 8, 18, 0),
#        datetime.datetime(2017, 12, 8, 15, 0),
#        datetime.datetime(2018, 8, 30, 0, 30),
#        datetime.datetime(2018, 1, 25, 10, 0),
#        datetime.datetime(2018, 2, 10, 17, 0),
#        datetime.datetime(2018, 2, 10, 14, 0),
#        datetime.datetime(2018, 4, 27, 17, 0),
#        datetime.datetime(2018, 4, 27, 14, 0),
#        datetime.datetime(2018, 6, 7, 16, 0),
#        datetime.datetime(2018, 6, 7, 13, 0),
#        datetime.datetime(2018, 3, 10, 17, 0),
#        datetime.datetime(2018, 3, 10, 14, 0),
#        datetime.datetime(2018, 8, 9, 15, 0),
#        datetime.datetime(2018, 11, 2, 15, 0),
#        datetime.datetime(2018, 11, 2, 12, 0),
#        datetime.datetime(2018, 9, 1, 16, 0),
#        datetime.datetime(2018, 9, 1, 13, 0),
#        datetime.datetime(2018, 3, 9, 17, 0),
#        datetime.datetime(2018, 3, 9, 14, 0),
#        datetime.datetime(2018, 2, 1, 18, 0),
#        datetime.datetime(2018, 2, 1, 15, 0),
#        datetime.datetime(2019, 5, 2, 17, 0),
#        datetime.datetime(2019, 5, 2, 14, 0),
#        datetime.datetime(2019, 4, 18, 15, 0),
#        datetime.datetime(2019, 4, 18, 12, 0),
#        datetime.datetime(2019, 2, 22, 16, 0),
#        datetime.datetime(2019, 2, 22, 13, 0),
#        datetime.datetime(2018, 10, 5, 15, 0),
#        datetime.datetime(2018, 10, 5, 12, 0),
#        datetime.datetime(2018, 7, 20, 15, 0),
#        datetime.datetime(2018, 7, 20, 12, 0),
#        datetime.datetime(2018, 10, 12, 17, 0),
#        datetime.datetime(2018, 10, 12, 14, 0),
#        datetime.datetime(2018, 5, 24, 17, 0),
#        datetime.datetime(2018, 5, 24, 14, 0),
#        datetime.datetime(2019, 5, 3, 16, 0),
#        datetime.datetime(2019, 5, 3, 13, 0),
#        datetime.datetime(2018, 3, 30, 15, 0),
#        datetime.datetime(2018, 3, 30, 12, 0),
#        datetime.datetime(2019, 5, 3, 17, 0),
#        datetime.datetime(2019, 5, 3, 14, 0),
#        datetime.datetime(2019, 1, 19, 17, 0),
#        datetime.datetime(2019, 1, 19, 14, 0),
#        datetime.datetime(2018, 8, 18, 16, 0),
#        datetime.datetime(2018, 8, 18, 13, 0),
#        datetime.datetime(2018, 4, 5, 13, 0),
#        datetime.datetime(2018, 6, 15, 16, 0),
#        datetime.datetime(2018, 6, 15, 13, 0),
#        datetime.datetime(2018, 3, 29, 16, 0),
#        datetime.datetime(2018, 3, 29, 13, 0),
#        datetime.datetime(2018, 5, 20, 18, 0),
#        datetime.datetime(2018, 5, 20, 13, 0),
#        datetime.datetime(2019, 5, 15, 16, 0),
#        datetime.datetime(2019, 5, 15, 13, 0),
#        datetime.datetime(2018, 7, 21, 17, 0),
#        datetime.datetime(2018, 7, 21, 14, 0),
#        datetime.datetime(2018, 6, 16, 17, 0),
#        datetime.datetime(2018, 6, 16, 14, 0),
#        datetime.datetime(2018, 3, 10, 18, 0),
#        datetime.datetime(2018, 3, 10, 15, 0),
#        datetime.datetime(2018, 2, 4, 1, 0),
#        datetime.datetime(2018, 1, 19, 16, 0),
#        datetime.datetime(2018, 1, 19, 13, 0),
#        datetime.datetime(2019, 1, 10, 16, 0),
#        datetime.datetime(2018, 10, 18, 15, 0),
#        datetime.datetime(2019, 4, 17, 15, 0),
#        datetime.datetime(2019, 5, 1, 15, 0),
#        datetime.datetime(2018, 8, 5, 15, 0),
#        datetime.datetime(2018, 2, 24, 10, 0),
#        datetime.datetime(2018, 3, 24, 10, 0),
#        datetime.datetime(2019, 2, 28, 10, 0),
#        datetime.datetime(2018, 4, 14, 9, 0),
#        datetime.datetime(2019, 4, 26, 9, 0),
#        datetime.datetime(2018, 11, 17, 10, 0),
#        datetime.datetime(2018, 10, 20, 9, 0),
#        datetime.datetime(2018, 5, 19, 9, 0),
#        datetime.datetime(2018, 12, 1, 10, 0),
#        datetime.datetime(2019, 5, 10, 16, 0),
#        datetime.datetime(2019, 5, 10, 13, 0),
#        datetime.datetime(2019, 2, 28, 17, 0),
#        datetime.datetime(2019, 2, 28, 14, 0),
#        datetime.datetime(2019, 4, 12, 16, 0),
#        datetime.datetime(2019, 4, 12, 13, 0),
#        datetime.datetime(2019, 1, 12, 16, 30),
#        datetime.datetime(2019, 1, 12, 13, 30),
#        datetime.datetime(2018, 12, 14, 18, 0),
#        datetime.datetime(2018, 12, 14, 14, 0),
#        datetime.datetime(2018, 11, 16, 17, 0),
#        datetime.datetime(2018, 11, 16, 14, 0),
#        datetime.datetime(2018, 10, 26, 15, 0),
#        datetime.datetime(2018, 10, 26, 12, 0),
#        datetime.datetime(2018, 3, 25, 16, 0),
#        datetime.datetime(2018, 3, 25, 13, 0),
#        datetime.datetime(2018, 1, 5, 18, 0),
#        datetime.datetime(2018, 1, 5, 15, 0),
#        datetime.datetime(2019, 4, 10, 15, 0),
#        datetime.datetime(2019, 5, 31, 0, 0),
#        datetime.datetime(2019, 2, 16, 17, 0),
#        datetime.datetime(2019, 2, 16, 14, 0),
#        datetime.datetime(2018, 10, 5, 16, 0),
#        datetime.datetime(2018, 10, 5, 13, 0),
#        datetime.datetime(2018, 4, 21, 17, 0),
#        datetime.datetime(2018, 4, 21, 14, 0),
#        datetime.datetime(2018, 7, 28, 16, 0),
#        datetime.datetime(2018, 7, 28, 13, 0),
#        datetime.datetime(2018, 3, 22, 17, 0),
#        datetime.datetime(2018, 3, 22, 14, 0),
#        datetime.datetime(2018, 8, 16, 15, 0),
#        datetime.datetime(2018, 5, 3, 15, 0),
#        datetime.datetime(2018, 7, 26, 15, 0),
#        datetime.datetime(2018, 3, 23, 15, 0),
#        datetime.datetime(2018, 3, 23, 12, 0),
#        datetime.datetime(2019, 2, 21, 16, 0),
#        datetime.datetime(2018, 4, 26, 15, 0),
#        datetime.datetime(2019, 1, 17, 16, 0),
#        datetime.datetime(2017, 12, 7, 16, 0),
#        datetime.datetime(2019, 2, 14, 16, 0),
#        datetime.datetime(2018, 8, 2, 15, 0),
#        datetime.datetime(2018, 6, 14, 15, 0),
#        datetime.datetime(2018, 6, 2, 16, 0),
#        datetime.datetime(2018, 6, 2, 13, 0),
#        datetime.datetime(2018, 3, 1, 17, 0),
#        datetime.datetime(2018, 3, 1, 14, 0),
#        datetime.datetime(2018, 1, 13, 18, 0),
#        datetime.datetime(2018, 1, 13, 15, 0),
#        datetime.datetime(2018, 4, 20, 15, 0),
#        datetime.datetime(2018, 4, 20, 12, 0),
#        datetime.datetime(2018, 4, 19, 15, 0),
#        datetime.datetime(2019, 5, 22, 15, 0),
#        datetime.datetime(2018, 4, 12, 15, 0),
#        datetime.datetime(2019, 3, 1, 17, 0),
#        datetime.datetime(2019, 3, 1, 14, 0),
#        datetime.datetime(2018, 8, 4, 17, 0),
#        datetime.datetime(2018, 8, 4, 14, 0),
#        datetime.datetime(2018, 7, 20, 17, 0),
#        datetime.datetime(2018, 7, 20, 14, 0),
#        datetime.datetime(2018, 5, 19, 17, 0),
#        datetime.datetime(2018, 5, 19, 14, 0),
#        datetime.datetime(2018, 1, 28, 18, 0),
#        datetime.datetime(2018, 1, 28, 15, 0),
#        datetime.datetime(2017, 12, 8, 17, 0),
#        datetime.datetime(2017, 12, 8, 14, 0),
#        datetime.datetime(2018, 8, 23, 15, 0),
#        datetime.datetime(2018, 5, 19, 16, 0),
#        datetime.datetime(2018, 5, 19, 13, 0),
#        datetime.datetime(2019, 2, 21, 10, 0),
#        datetime.datetime(2018, 3, 1, 16, 0), '2/29/2019  5:00:00 PM',
#        '2/29/2019  2:00:00 PM', datetime.datetime(2018, 12, 13, 16, 0),
#        datetime.datetime(2018, 7, 19, 1, 0),
#        datetime.datetime(2019, 1, 17, 3, 0),
#        datetime.datetime(2019, 2, 16, 3, 0),
#        datetime.datetime(2018, 11, 24, 10, 0),
#        datetime.datetime(2018, 9, 15, 16, 0),
#        datetime.datetime(2018, 9, 15, 13, 0),
#        datetime.datetime(2018, 6, 7, 15, 0),
#        datetime.datetime(2018, 3, 3, 18, 0),
#        datetime.datetime(2018, 3, 3, 15, 0),
#        datetime.datetime(2019, 5, 15, 15, 0),
#        datetime.datetime(2018, 10, 4, 15, 0),
#        datetime.datetime(2018, 5, 24, 9, 0),
#        datetime.datetime(2018, 6, 29, 16, 0),
#        datetime.datetime(2018, 6, 29, 13, 0),
#        datetime.datetime(2018, 4, 13, 17, 0),
#        datetime.datetime(2018, 4, 13, 14, 0),
#        datetime.datetime(2018, 8, 31, 16, 0),
#        datetime.datetime(2018, 8, 31, 13, 0),
#        datetime.datetime(2018, 10, 27, 17, 0),
#        datetime.datetime(2018, 10, 27, 14, 0),
#        datetime.datetime(2018, 9, 29, 16, 0),
#        datetime.datetime(2018, 9, 29, 13, 0),
#        datetime.datetime(2018, 9, 23, 5, 0),
#        datetime.datetime(2018, 7, 21, 15, 0),
#        datetime.datetime(2018, 7, 21, 12, 0),
#        datetime.datetime(2019, 1, 11, 17, 0),
#        datetime.datetime(2019, 1, 11, 14, 0),
#        datetime.datetime(2018, 11, 30, 17, 0),
#        datetime.datetime(2018, 11, 30, 14, 0),
#        datetime.datetime(2019, 5, 16, 17, 0),
#        datetime.datetime(2019, 5, 16, 14, 0),
#        datetime.datetime(2019, 3, 22, 17, 0),
#        datetime.datetime(2019, 3, 22, 14, 0),
#        datetime.datetime(2018, 12, 20, 18, 0),
#        datetime.datetime(2018, 12, 20, 15, 0),
#        datetime.datetime(2018, 11, 3, 17, 0),
#        datetime.datetime(2018, 11, 3, 14, 0),
#        datetime.datetime(2019, 4, 19, 17, 0),
#        datetime.datetime(2019, 4, 19, 14, 0),
#        datetime.datetime(2019, 1, 4, 18, 0),
#        datetime.datetime(2019, 1, 4, 15, 0),
#        datetime.datetime(2019, 1, 19, 18, 0),
#        datetime.datetime(2019, 1, 19, 15, 0),
#        datetime.datetime(2018, 3, 8, 16, 0),
#        datetime.datetime(2018, 4, 5, 15, 0),
#        datetime.datetime(2018, 7, 5, 15, 0),
#        datetime.datetime(2018, 1, 11, 16, 0),
#        datetime.datetime(2018, 6, 28, 9, 0),
#        datetime.datetime(2019, 5, 14, 18, 0),
#        datetime.datetime(2019, 5, 15, 18, 0),
#        datetime.datetime(2018, 10, 11, 16, 0),
#        datetime.datetime(2018, 10, 11, 13, 0),
#        datetime.datetime(2019, 1, 13, 4, 0),
#        datetime.datetime(2018, 7, 12, 1, 0),
#        datetime.datetime(2018, 6, 14, 16, 0),
#        datetime.datetime(2018, 6, 14, 13, 0),
#        datetime.datetime(2019, 4, 18, 17, 0),
#        datetime.datetime(2019, 4, 18, 14, 0),
#        datetime.datetime(2019, 2, 14, 17, 0),
#        datetime.datetime(2019, 2, 14, 14, 0),
#        datetime.datetime(2018, 11, 17, 18, 0),
#        datetime.datetime(2018, 11, 17, 15, 0),
#        datetime.datetime(2018, 7, 21, 16, 0),
#        datetime.datetime(2018, 7, 21, 13, 0),
#        datetime.datetime(2018, 4, 5, 16, 0),
#        datetime.datetime(2018, 1, 24, 17, 0),
#        datetime.datetime(2018, 1, 24, 14, 0),
#        datetime.datetime(2018, 7, 12, 15, 0),
#        datetime.datetime(2018, 2, 8, 16, 0),
#        datetime.datetime(2018, 9, 29, 9, 0),
#        datetime.datetime(2019, 5, 30, 0, 0),
#        datetime.datetime(2019, 3, 20, 15, 0),
#        datetime.datetime(2018, 5, 25, 17, 0),
#        datetime.datetime(2018, 5, 25, 14, 0),
#        datetime.datetime(2019, 5, 10, 17, 0),
#        datetime.datetime(2019, 5, 10, 14, 0),
#        datetime.datetime(2018, 8, 10, 17, 0),
#        datetime.datetime(2018, 8, 10, 14, 0),
#        datetime.datetime(2019, 1, 17, 17, 0),
#        datetime.datetime(2019, 1, 17, 14, 0),
#        datetime.datetime(2019, 5, 16, 15, 0),
#        datetime.datetime(2019, 5, 16, 12, 0),
#        datetime.datetime(2019, 3, 8, 17, 0),
#        datetime.datetime(2019, 3, 8, 14, 0),
#        datetime.datetime(2018, 12, 6, 17, 0),
#        datetime.datetime(2018, 12, 6, 14, 0),
#        datetime.datetime(2018, 10, 27, 16, 0),
#        datetime.datetime(2018, 10, 27, 13, 0),
#        datetime.datetime(2018, 9, 6, 16, 0),
#        datetime.datetime(2018, 9, 6, 13, 0),
#        datetime.datetime(2018, 7, 5, 16, 0),
#        datetime.datetime(2018, 7, 5, 13, 0),
#        datetime.datetime(2018, 4, 12, 16, 0),
#        datetime.datetime(2018, 4, 12, 13, 0),
#        datetime.datetime(2018, 1, 26, 16, 0),
#        datetime.datetime(2018, 1, 26, 13, 0),
#        datetime.datetime(2017, 12, 1, 16, 0),
#        datetime.datetime(2017, 12, 1, 13, 0),
#        datetime.datetime(2018, 5, 25, 15, 0),
#        datetime.datetime(2018, 5, 25, 12, 0),
#        datetime.datetime(2018, 12, 13, 4, 0),
#        datetime.datetime(2018, 11, 29, 18, 0),
#        datetime.datetime(2018, 11, 29, 15, 0),
#        datetime.datetime(2019, 1, 12, 18, 0),
#        datetime.datetime(2019, 1, 12, 15, 0),
#        datetime.datetime(2019, 3, 14, 15, 0),
#        datetime.datetime(2019, 3, 14, 12, 0),
#        datetime.datetime(2019, 1, 3, 17, 0),
#        datetime.datetime(2019, 1, 3, 14, 0),
#        datetime.datetime(2018, 7, 12, 16, 0),
#        datetime.datetime(2018, 7, 12, 13, 0),
#        datetime.datetime(2018, 5, 17, 15, 0),
#        datetime.datetime(2018, 2, 28, 10, 0),
#        datetime.datetime(2018, 9, 1, 17, 0),
#        datetime.datetime(2018, 9, 1, 14, 0),
#        datetime.datetime(2018, 4, 14, 16, 0),
#        datetime.datetime(2018, 4, 14, 13, 0),
#        datetime.datetime(2018, 7, 13, 16, 0),
#        datetime.datetime(2018, 7, 13, 13, 0),
#        datetime.datetime(2018, 10, 26, 17, 0),
#        datetime.datetime(2018, 10, 26, 14, 0),
#        datetime.datetime(2019, 3, 27, 15, 0),
#        datetime.datetime(2018, 4, 20, 17, 0),
#        datetime.datetime(2018, 4, 20, 14, 0),
#        datetime.datetime(2018, 12, 8, 18, 0),
#        datetime.datetime(2018, 12, 8, 15, 0),
#        datetime.datetime(2018, 2, 10, 18, 0),
#        datetime.datetime(2018, 2, 10, 15, 0),
#        datetime.datetime(2018, 3, 2, 18, 0),
#        datetime.datetime(2018, 3, 2, 15, 0),
#        datetime.datetime(2019, 2, 2, 18, 0),
#        datetime.datetime(2019, 2, 2, 15, 0),
#        datetime.datetime(2018, 8, 25, 17, 0),
#        datetime.datetime(2018, 8, 25, 14, 0),
#        datetime.datetime(2018, 10, 19, 15, 0),
#        datetime.datetime(2018, 10, 19, 12, 0),
#        datetime.datetime(2019, 5, 29, 0, 0),
#        datetime.datetime(2019, 2, 2, 17, 0),
#        datetime.datetime(2019, 2, 2, 14, 0),
#        datetime.datetime(2018, 9, 27, 16, 0),
#        datetime.datetime(2018, 9, 27, 13, 0),
#        datetime.datetime(2018, 10, 12, 15, 0),
#        datetime.datetime(2018, 10, 12, 12, 0),
#        datetime.datetime(2018, 6, 22, 17, 0),
#        datetime.datetime(2018, 6, 22, 14, 0),
#        datetime.datetime(2018, 3, 31, 16, 0),
#        datetime.datetime(2018, 3, 31, 13, 0),
#        datetime.datetime(2018, 2, 24, 18, 0),
#        datetime.datetime(2018, 2, 24, 15, 0),
#        datetime.datetime(2018, 1, 20, 17, 0),
#        datetime.datetime(2018, 1, 20, 14, 0),
#        datetime.datetime(2018, 6, 14, 9, 30),
#        datetime.datetime(2019, 5, 17, 16, 0),
#        datetime.datetime(2019, 5, 17, 13, 0),
#        datetime.datetime(2019, 2, 21, 17, 0),
#        datetime.datetime(2019, 2, 21, 14, 0),
#        datetime.datetime(2018, 11, 15, 17, 0),
#        datetime.datetime(2018, 11, 15, 14, 0),
#        datetime.datetime(2018, 8, 11, 16, 0),
#        datetime.datetime(2018, 8, 11, 13, 0),
#        datetime.datetime(2018, 12, 15, 18, 0),
#        datetime.datetime(2018, 12, 15, 15, 0),
#        datetime.datetime(2018, 9, 7, 17, 0),
#        datetime.datetime(2018, 6, 29, 15, 0),
#        datetime.datetime(2018, 6, 29, 12, 0),
#        datetime.datetime(2018, 1, 31, 17, 0),
#        datetime.datetime(2018, 1, 31, 14, 0),
#        datetime.datetime(2019, 3, 6, 17, 0),
#        datetime.datetime(2019, 3, 6, 14, 0),
#        datetime.datetime(2018, 4, 19, 9, 0),
#        datetime.datetime(2018, 10, 13, 17, 0),
#        datetime.datetime(2018, 10, 13, 14, 0),
#        datetime.datetime(2018, 3, 23, 17, 0),
#        datetime.datetime(2018, 3, 23, 14, 0),
#        datetime.datetime(2018, 1, 13, 17, 0),
#        datetime.datetime(2018, 1, 13, 14, 0),
#        datetime.datetime(2018, 8, 9, 16, 0),
#        datetime.datetime(2018, 8, 9, 13, 0),
#        datetime.datetime(2018, 9, 29, 17, 0),
#        datetime.datetime(2018, 9, 29, 14, 0),
#        datetime.datetime(2019, 2, 23, 18, 0),
#        datetime.datetime(2019, 2, 23, 15, 0),
#        datetime.datetime(2018, 12, 14, 16, 0),
#        datetime.datetime(2018, 12, 14, 13, 0),
#        datetime.datetime(2018, 10, 25, 16, 0),
#        datetime.datetime(2018, 10, 25, 13, 0),
#        datetime.datetime(2018, 11, 18, 18, 0),
#        datetime.datetime(2018, 11, 18, 15, 0),
#        datetime.datetime(2018, 9, 8, 16, 0),
#        datetime.datetime(2018, 9, 8, 13, 0),
#        datetime.datetime(2019, 3, 15, 17, 0),
#        datetime.datetime(2019, 3, 15, 14, 0),
#        datetime.datetime(2019, 1, 5, 17, 0),
#        datetime.datetime(2019, 1, 5, 14, 0),
#        datetime.datetime(2018, 5, 11, 15, 0),
#        datetime.datetime(2018, 5, 11, 12, 0),
#        datetime.datetime(2017, 12, 14, 17, 0),
#        datetime.datetime(2017, 12, 14, 14, 0),
#        datetime.datetime(2018, 8, 22, 9, 0),
#        datetime.datetime(2019, 4, 26, 17, 0),
#        datetime.datetime(2019, 4, 26, 14, 0),
#        datetime.datetime(2019, 3, 21, 15, 0),
#        datetime.datetime(2019, 3, 21, 12, 0),
#        datetime.datetime(2018, 9, 15, 17, 0),
#        datetime.datetime(2018, 9, 15, 14, 0),
#        datetime.datetime(2018, 7, 14, 17, 0),
#        datetime.datetime(2018, 7, 14, 14, 0),
#        datetime.datetime(2017, 12, 15, 17, 0),
#        datetime.datetime(2017, 12, 15, 14, 0),
#        datetime.datetime(2018, 5, 12, 16, 0),
#        datetime.datetime(2018, 5, 12, 13, 0),
#        datetime.datetime(2018, 11, 3, 16, 0),
#        datetime.datetime(2018, 11, 3, 13, 0),
#        datetime.datetime(2019, 4, 5, 16, 0),
#        datetime.datetime(2019, 4, 5, 13, 0),
#        datetime.datetime(2019, 2, 8, 18, 0),
#        datetime.datetime(2019, 2, 8, 15, 0),
#        datetime.datetime(2018, 5, 24, 15, 0),
#        datetime.datetime(2018, 10, 25, 4, 0),
#        datetime.datetime(2018, 10, 6, 16, 0),
#        datetime.datetime(2018, 10, 6, 13, 0),
#        datetime.datetime(2019, 3, 13, 16, 0),
#        datetime.datetime(2019, 3, 13, 13, 0),
#        datetime.datetime(2018, 10, 5, 17, 0),
#        datetime.datetime(2018, 10, 5, 14, 0),
#        datetime.datetime(2018, 8, 17, 17, 0),
#        datetime.datetime(2018, 8, 17, 14, 0),
#        datetime.datetime(2017, 12, 2, 17, 0),
#        datetime.datetime(2017, 12, 2, 14, 0),
#        datetime.datetime(2018, 5, 31, 15, 0),
#        datetime.datetime(2018, 5, 26, 17, 0),
#        datetime.datetime(2018, 5, 26, 14, 0),
#        datetime.datetime(2018, 11, 29, 4, 0),
#        datetime.datetime(2018, 1, 18, 17, 0),
#        datetime.datetime(2018, 1, 18, 14, 0),
#        datetime.datetime(2018, 2, 3, 17, 0),
#        datetime.datetime(2018, 2, 3, 14, 0),
#        datetime.datetime(2018, 12, 21, 17, 0),
#        datetime.datetime(2018, 12, 21, 14, 0),
#        datetime.datetime(2018, 6, 23, 17, 0),
#        datetime.datetime(2018, 6, 23, 14, 0),
#        datetime.datetime(2018, 10, 11, 15, 0),
#        datetime.datetime(2019, 4, 20, 6, 30),
#        datetime.datetime(2019, 4, 20, 2, 0),
#        datetime.datetime(2019, 4, 17, 16, 0),
#        datetime.datetime(2019, 4, 17, 13, 0),
#        datetime.datetime(2018, 10, 25, 15, 0),
#        datetime.datetime(2019, 5, 1, 16, 0),
#        datetime.datetime(2019, 5, 1, 13, 0),
#        datetime.datetime(2019, 2, 16, 18, 0),
#        datetime.datetime(2019, 2, 16, 15, 0),
#        datetime.datetime(2018, 10, 13, 16, 0),
#        datetime.datetime(2018, 10, 13, 13, 0),
#        datetime.datetime(2018, 7, 14, 16, 0),
#        datetime.datetime(2018, 7, 14, 13, 0),
#        datetime.datetime(2018, 3, 15, 15, 0),
#        datetime.datetime(2018, 9, 20, 15, 0),
#        datetime.datetime(2018, 8, 16, 16, 0),
#        datetime.datetime(2018, 8, 16, 13, 0),
#        datetime.datetime(2019, 3, 29, 17, 0),
#        datetime.datetime(2019, 3, 29, 14, 0),
#        datetime.datetime(2018, 6, 30, 17, 0),
#        datetime.datetime(2018, 6, 30, 14, 0),
#        datetime.datetime(2018, 4, 7, 17, 0),
#        datetime.datetime(2018, 4, 7, 14, 0),
#        datetime.datetime(2018, 11, 9, 16, 0),
#        datetime.datetime(2018, 11, 9, 13, 0),
#        datetime.datetime(2019, 4, 11, 17, 0),
#        datetime.datetime(2019, 4, 11, 14, 0),
#        datetime.datetime(2019, 2, 1, 18, 0),
#        datetime.datetime(2019, 2, 1, 15, 0),
#        datetime.datetime(2018, 12, 1, 17, 0),
#        datetime.datetime(2018, 12, 1, 14, 0),
#        datetime.datetime(2018, 9, 20, 16, 0),
#        datetime.datetime(2018, 9, 20, 13, 0),
#        datetime.datetime(2018, 6, 21, 16, 0),
#        datetime.datetime(2018, 6, 21, 13, 0),
#        datetime.datetime(2018, 3, 8, 17, 0),
#        datetime.datetime(2018, 3, 8, 14, 0),
#        datetime.datetime(2018, 1, 19, 17, 0),
#        datetime.datetime(2018, 1, 19, 14, 0),
#        datetime.datetime(2019, 4, 11, 15, 0),
#        datetime.datetime(2019, 4, 11, 12, 0),
#        datetime.datetime(2019, 4, 24, 16, 0),
#        datetime.datetime(2019, 4, 24, 13, 0),
#        datetime.datetime(2018, 11, 22, 17, 0),
#        datetime.datetime(2018, 11, 22, 14, 0),
#        datetime.datetime(2019, 3, 27, 16, 0),
#        datetime.datetime(2019, 3, 27, 13, 0),
#        datetime.datetime(2018, 5, 12, 17, 0),
#        datetime.datetime(2018, 5, 12, 14, 0),
#        datetime.datetime(2018, 1, 20, 18, 0),
#        datetime.datetime(2018, 1, 20, 15, 0),
#        datetime.datetime(2018, 3, 16, 17, 0),
#        datetime.datetime(2018, 3, 16, 14, 0),
#        datetime.datetime(2019, 5, 17, 17, 0),
#        datetime.datetime(2019, 5, 17, 14, 0),
#        datetime.datetime(2019, 5, 8, 16, 0),
#        datetime.datetime(2019, 5, 8, 13, 0),
#        datetime.datetime(2018, 7, 27, 17, 0),
#        datetime.datetime(2018, 7, 27, 14, 0),
#        datetime.datetime(2018, 3, 30, 17, 0),
#        datetime.datetime(2018, 3, 30, 14, 0),
#        datetime.datetime(2018, 2, 22, 17, 0),
#        datetime.datetime(2018, 2, 22, 14, 0),
#        datetime.datetime(2019, 1, 31, 16, 0),
#        datetime.datetime(2019, 3, 15, 16, 0),
#        datetime.datetime(2019, 3, 15, 13, 0),
#        datetime.datetime(2018, 5, 5, 16, 0),
#        datetime.datetime(2018, 5, 5, 13, 0),
#        datetime.datetime(2018, 3, 2, 16, 0),
#        datetime.datetime(2018, 3, 2, 13, 0),
#        datetime.datetime(2018, 11, 15, 16, 0),
#        datetime.datetime(2018, 10, 20, 17, 0),
#        datetime.datetime(2018, 10, 20, 14, 0),
#        datetime.datetime(2018, 8, 11, 15, 0),
#        datetime.datetime(2018, 8, 11, 12, 0),
#        datetime.datetime(2018, 6, 8, 15, 0),
#        datetime.datetime(2018, 6, 8, 12, 0),
#        datetime.datetime(2018, 3, 16, 15, 0),
#        datetime.datetime(2018, 3, 16, 12, 0),
#        datetime.datetime(2019, 1, 26, 17, 0),
#        datetime.datetime(2019, 1, 26, 14, 0),
#        datetime.datetime(2018, 9, 28, 17, 0),
#        datetime.datetime(2018, 9, 28, 14, 0),
#        datetime.datetime(2018, 8, 25, 16, 0),
#        datetime.datetime(2018, 8, 25, 13, 0),
#        datetime.datetime(2019, 1, 24, 18, 0),
#        datetime.datetime(2019, 1, 24, 15, 0),
#        datetime.datetime(2018, 12, 14, 15, 0),
#        datetime.datetime(2018, 11, 8, 17, 0),
#        datetime.datetime(2018, 11, 8, 14, 0),
#        datetime.datetime(2019, 5, 22, 16, 0),
#        datetime.datetime(2019, 5, 22, 13, 0),
#        datetime.datetime(2019, 2, 9, 18, 0),
#        datetime.datetime(2019, 2, 9, 15, 0),
#        datetime.datetime(2018, 11, 10, 17, 0),
#        datetime.datetime(2018, 11, 10, 14, 0),
#        datetime.datetime(2019, 3, 13, 15, 0),
#        datetime.datetime(2019, 2, 28, 16, 0),
#        datetime.datetime(2018, 7, 19, 16, 0),
#        datetime.datetime(2018, 7, 19, 13, 0),
#        datetime.datetime(2018, 2, 15, 13, 0),
#        datetime.datetime(2018, 12, 29, 18, 0),
#        datetime.datetime(2018, 12, 29, 15, 0),
#        datetime.datetime(2019, 5, 16, 18, 0),
#        datetime.datetime(2019, 3, 22, 16, 0),
#        datetime.datetime(2019, 3, 22, 13, 0),
#        datetime.datetime(2018, 12, 1, 16, 0),
#        datetime.datetime(2018, 12, 1, 13, 0),
#        datetime.datetime(2018, 8, 24, 15, 0),
#        datetime.datetime(2018, 8, 24, 12, 0),
#        datetime.datetime(2018, 4, 13, 15, 0),
#        datetime.datetime(2018, 4, 13, 12, 0),
#        datetime.datetime(2019, 4, 4, 15, 0),
#        datetime.datetime(2019, 4, 4, 12, 0),
#        datetime.datetime(2018, 2, 22, 16, 0),
#        datetime.datetime(2019, 1, 25, 16, 0),
#        datetime.datetime(2019, 1, 25, 13, 0),
#        datetime.datetime(2019, 1, 10, 17, 0),
#        datetime.datetime(2019, 1, 10, 14, 0),
#        datetime.datetime(2018, 11, 30, 18, 0),
#        datetime.datetime(2018, 11, 30, 15, 0),
#        datetime.datetime(2018, 8, 23, 17, 0),
#        datetime.datetime(2018, 8, 23, 14, 0),
#        datetime.datetime(2018, 2, 9, 17, 0),
#        datetime.datetime(2018, 2, 9, 14, 0),
#        datetime.datetime(2018, 2, 14, 3, 0),
#        datetime.datetime(2018, 5, 31, 16, 0),
#        datetime.datetime(2018, 5, 31, 13, 0),
#        datetime.datetime(2018, 3, 3, 17, 0),
#        datetime.datetime(2018, 3, 3, 14, 0),
#        datetime.datetime(2018, 6, 9, 17, 0),
#        datetime.datetime(2018, 6, 9, 14, 0),
#        datetime.datetime(2019, 4, 3, 16, 0),
#        datetime.datetime(2019, 4, 3, 13, 0),
#        datetime.datetime(2019, 3, 20, 16, 0),
#        datetime.datetime(2019, 3, 20, 13, 0),
#        datetime.datetime(2018, 11, 16, 18, 0),
#        datetime.datetime(2018, 11, 16, 15, 0),
#        datetime.datetime(2018, 9, 7, 15, 30),
#        datetime.datetime(2018, 12, 1, 18, 0),
#        datetime.datetime(2018, 12, 1, 15, 0),
#        datetime.datetime(2018, 8, 31, 17, 0),
#        datetime.datetime(2018, 8, 31, 14, 0),
#        datetime.datetime(2018, 7, 13, 17, 0),
#        datetime.datetime(2018, 7, 13, 14, 0),
#        datetime.datetime(2018, 5, 18, 17, 0),
#        datetime.datetime(2018, 5, 18, 14, 0),
#        datetime.datetime(2018, 9, 13, 5, 0),
#        datetime.datetime(2019, 4, 25, 17, 0),
#        datetime.datetime(2019, 4, 25, 14, 0),
#        datetime.datetime(2019, 2, 22, 18, 0),
#        datetime.datetime(2019, 2, 22, 15, 0),
#        datetime.datetime(2018, 7, 7, 17, 0),
#        datetime.datetime(2018, 7, 7, 14, 0),
#        datetime.datetime(2018, 4, 26, 16, 0),
#        datetime.datetime(2018, 4, 26, 13, 0),
#        datetime.datetime(2018, 2, 23, 16, 0),
#        datetime.datetime(2018, 2, 23, 13, 0),
#        datetime.datetime(2018, 1, 24, 16, 0),
#        datetime.datetime(2018, 1, 24, 13, 0),
#        datetime.datetime(2017, 12, 15, 18, 0),
#        datetime.datetime(2017, 12, 15, 15, 0),
#        datetime.datetime(2019, 3, 7, 16, 0),
#        datetime.datetime(2019, 3, 7, 13, 0),
#        datetime.datetime(2019, 1, 18, 16, 0),
#        datetime.datetime(2019, 1, 18, 13, 0),
#        datetime.datetime(2018, 12, 21, 16, 0),
#        datetime.datetime(2018, 12, 21, 13, 0),
#        datetime.datetime(2018, 11, 23, 16, 0),
#        datetime.datetime(2018, 11, 23, 13, 0),
#        datetime.datetime(2018, 11, 10, 18, 0),
#        datetime.datetime(2018, 11, 10, 15, 0),
#        datetime.datetime(2018, 3, 24, 15, 0),
#        datetime.datetime(2018, 4, 27, 15, 0),
#        datetime.datetime(2018, 4, 27, 12, 0),
#        datetime.datetime(2019, 5, 23, 15, 0),
#        datetime.datetime(2019, 5, 23, 12, 0),
#        datetime.datetime(2019, 2, 15, 16, 0),
#        datetime.datetime(2019, 2, 15, 13, 0),
#        datetime.datetime(2018, 9, 21, 16, 0),
#        datetime.datetime(2018, 9, 21, 13, 0),
#        datetime.datetime(2018, 7, 26, 16, 0),
#        datetime.datetime(2018, 7, 26, 13, 0),
#        datetime.datetime(2018, 5, 10, 17, 0),
#        datetime.datetime(2018, 5, 10, 14, 0),
#        datetime.datetime(2018, 1, 11, 18, 0),
#        datetime.datetime(2018, 1, 11, 15, 0),
#        datetime.datetime(2019, 4, 5, 17, 0),
#        datetime.datetime(2019, 4, 5, 14, 0),
#        datetime.datetime(2018, 7, 6, 17, 0),
#        datetime.datetime(2018, 7, 6, 14, 0),
#        datetime.datetime(2018, 7, 26, 18, 0),
#        datetime.datetime(2018, 7, 26, 12, 0),
#        datetime.datetime(2018, 9, 7, 18, 30),
#        datetime.datetime(2019, 5, 9, 17, 0),
#        datetime.datetime(2019, 5, 9, 14, 0),
#        datetime.datetime(2019, 3, 14, 17, 0),
#        datetime.datetime(2019, 3, 14, 14, 0),
#        datetime.datetime(2019, 1, 11, 18, 0),
#        datetime.datetime(2019, 1, 11, 15, 0),
#        datetime.datetime(2018, 8, 18, 17, 0),
#        datetime.datetime(2018, 8, 18, 14, 0),
#        datetime.datetime(2019, 4, 24, 15, 0),
#        datetime.datetime(2018, 5, 24, 12, 0),
#        datetime.datetime(2018, 6, 15, 15, 0),
#        datetime.datetime(2018, 6, 15, 12, 0),
#        datetime.datetime(2018, 4, 19, 16, 0),
#        datetime.datetime(2018, 4, 19, 13, 0),
#        datetime.datetime(2019, 4, 10, 16, 0),
#        datetime.datetime(2019, 4, 10, 13, 0),
#        datetime.datetime(2018, 11, 1, 15, 0),
#        datetime.datetime(2018, 6, 29, 17, 0),
#        datetime.datetime(2018, 6, 29, 14, 0),
#        datetime.datetime(2018, 7, 27, 16, 0),
#        datetime.datetime(2018, 7, 27, 13, 0),
#        datetime.datetime(2018, 9, 28, 15, 0),
#        datetime.datetime(2018, 9, 28, 12, 0),
#        datetime.datetime(2018, 1, 19, 18, 0),
#        datetime.datetime(2018, 1, 19, 15, 0),
#        datetime.datetime(2018, 9, 27, 15, 0),
#        datetime.datetime(2019, 3, 6, 16, 0),
#        datetime.datetime(2018, 6, 6, 12, 30),
#        datetime.datetime(2018, 12, 7, 16, 0),
#        datetime.datetime(2018, 12, 7, 13, 0),
#        datetime.datetime(2018, 12, 13, 18, 0),
#        datetime.datetime(2018, 12, 13, 15, 0),
#        datetime.datetime(2018, 6, 16, 17, 30)], dtype=object)

# %%
#Attempt to change to datetime object yields ParserError: day is out of range for month: 2/29/2019  4:00:00 PM
pd.to_datetime(data['Rating Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     656         except ValueError as e:
# --> 657             six.raise_from(ParserError(e.args[0] + ": %s", timestr), e)
#     658
#
# ~/opt/anaconda3/lib/python3.8/site-packages/six.py in raise_from(value, from_value)
#
# ParserError: day is out of range for month: 2/29/2019  4:00:00 PM
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-650-875c6ffc131e> in <module>
#       1 #Attempt to change to datetime object yields ParserError: day is out of range for month: 2/29/2019  4:00:00 PM
# ----> 2 pd.to_datetime(data['Rating Date'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     722                 result = result.tz_localize(tz)
#     723     elif isinstance(arg, ABCSeries):
# --> 724         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     725         if not cache_array.empty:
#     726             result = arg.map(cache_array)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     150         unique_dates = unique(arg)
#     151         if len(unique_dates) < len(arg):
# --> 152             cache_dates = convert_listlike(unique_dates, format)
#     153             cache_array = Series(cache_dates, index=unique_dates)
#     154     return cache_array
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     438         assert format is None or infer_datetime_format
#     439         utc = tz == "utc"
# --> 440         result, tz_parsed = objects_to_datetime64ns(
#     441             arg,
#     442             dayfirst=dayfirst,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1861             return values.view("i8"), tz_parsed
#    1862         except (ValueError, TypeError):
# -> 1863             raise e
#    1864
#    1865     if tz_parsed is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1846
#    1847     try:
# -> 1848         result, tz_parsed = tslib.array_to_datetime(
#    1849             data,
#    1850             errors=errors,
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
# --> 657             six.raise_from(ParserError(e.args[0] + ": %s", timestr), e)
#     658
#     659         if not ignoretz:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/six.py in raise_from(value, from_value)
#
# ParserError: day is out of range for month: 2/29/2019  4:00:00 PM

# %%
#find number of rows with 2/29/2019, a leap year
data['Rating Date'].str.contains('2/29/2019').value_counts()
# Out:
# True    100
# Name: Rating Date, dtype: int64

# %%
#display sample to ensure nothing out of the ordinary about these rows. 
data[data['Rating Date'].str.contains('2/29/2019',na=False)]
# Out:
#                 Rating Date  \
# 2144  2/29/2019  4:00:00 PM
# 2145  2/29/2019  4:00:00 PM
# 2146  2/29/2019  4:00:00 PM
# 2147  2/29/2019  4:00:00 PM
# 2148  2/29/2019  4:00:00 PM
# ...                     ...
# 7906  2/29/2019  2:00:00 PM
# 7907  2/29/2019  2:00:00 PM
# 7908  2/29/2019  2:00:00 PM
# 7909  2/29/2019  2:00:00 PM
# 7910  2/29/2019  2:00:00 PM
#
#                                           Webinar Title  \
# 2144                            What Is Virtualization?
# 2145                            What Is Virtualization?
# 2146                            What Is Virtualization?
# 2147                            What Is Virtualization?
# 2148                            What Is Virtualization?
# ...                                                 ...
# 7906  DattoCon Release Debrief for Unified Continuit...
# 7907  DattoCon Release Debrief for Unified Continuit...
# 7908  DattoCon Release Debrief for Unified Continuit...
# 7909  DattoCon Release Debrief for Unified Continuit...
# 7910  DattoCon Release Debrief for Unified Continuit...
#
#                                                 Comment  Rating  \
# 2144                                         no comment       4
# 2145                                         no comment       4
# 2146  good overview of the considerations for both t...       5
# 2147                                         no comment       4
# 2148                                         no comment       5
# ...                                                 ...     ...
# 7906       Some slides were not clear in their message.       4
# 7907                                         no comment       5
# 7908                                         no comment       4
# 7909  Very Useful. Can I please have slides used for...       4
# 7910                                         no comment       5
#
#       Comment Length
# 2144               1
# 2145               1
# 2146              51
# 2147               1
# 2148               1
# ...              ...
# 7906              44
# 7907               1
# 7908               1
# 7909              59
# 7910               1
#
# [100 rows x 5 columns]

# %%
#drop the 100 rows for expediency. Check that number rows = 20570.
data = data[~data['Rating Date'].str.contains('2/29/2019',na=False)]
data.shape
# Out:
# (20570, 5)

# %%
#convert to datetime object now that leap year dropped
data['Rating Date'] = pd.to_datetime(data['Rating Date'])

# %%
#add comment_id column for potential joining in Tableau
data['comment_id'] = data.index+1
data.shape
# Out:
# (20570, 6)

# %%
#tokenize and convert timestamp data to string to construct webinar_id
data['hour'] = data['Rating Date'].dt.hour.apply(str)
data['day'] = data['Rating Date'].dt.day.apply(str)
data['month'] = data['Rating Date'].dt.month.apply(str)
data['year'] = data['Rating Date'].dt.year.apply(str)
data.hour.dtypes
# Out:
# dtype('O')

# %%
#add unique id for each webinar + time combination
data['webinar_id'] = pd.factorize(data['Webinar Title']+data['hour']+data['day']+data['month']+data['year'])[0]

# %%
#drop helper columns
drop_list = ['hour','day','month','year']
data = data.drop(data[drop_list], axis=1)
data.head()
# Out:
#               Rating Date                                      Webinar Title  \
# 0     2019-01-19 10:00:00  Channel Security Experts Deep Dive: The Anatom...
# 1     2019-01-19 10:00:00  Channel Security Experts Deep Dive: The Anatom...
# 2     2019-01-19 10:00:00  Channel Security Experts Deep Dive: The Anatom...
# 3     2019-01-19 10:00:00  Channel Security Experts Deep Dive: The Anatom...
# 4     2019-01-19 10:00:00  Channel Security Experts Deep Dive: The Anatom...
# ...                   ...                                                ...
# 20665 2018-06-16 17:30:00  Developing an Effective Regime to Back up Your...
# 20666 2018-06-16 17:30:00  Developing an Effective Regime to Back up Your...
# 20667 2018-06-16 17:30:00  Developing an Effective Regime to Back up Your...
# 20668 2018-06-16 17:30:00  Developing an Effective Regime to Back up Your...
# 20669 2018-06-16 17:30:00  Developing an Effective Regime to Back up Your...
#
#                                                  Comment  Rating  \
# 0                                             no comment       4
# 1      interessanti spunti da approfondire soprattuto...       4
# 2                                             no comment       4
# 3                                             no comment       1
# 4                                             no comment       4
# ...                                                  ...     ...
# 20665                                         no comment       4
# 20666                                         no comment       3
# 20667                                         no comment       4
# 20668                                         no comment       4
# 20669                                 Helpful, thank you       4
#
#        Comment Length  comment_id  webinar_id
# 0                   1           1           0
# 1                  68           2           0
# 2                   1           3           0
# 3                   1           4           0
# 4                   1           5           0
# ...               ...         ...         ...
# 20665               1       20666         843
# 20666               1       20667         843
# 20667               1       20668         843
# 20668               1       20669         843
# 20669              18       20670         843
#
# [20570 rows x 7 columns]

# %%
#export w/o index
data.to_excel("datto_exercise_cleaned_new.xlsx",index = False)
